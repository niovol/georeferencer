# %%
from main import process_folder
process_folder("/layouts/layout_2021-08-16.tif", "1_20", "output")
# Out:
# crop_3_2_0000.tif
# Number of matches in 0 channel:  261
# Number of matches in 1 channel:  306
# Number of matches in 2 channel:  261
# Number of matches in 3 channel:  338
# Corners: [(426282.23692256946, 5735811.33277374), (438046.6478503742, 5735655.059010395), (437794.93308025674, 5716764.262450528), (426030.522152452, 5716920.536213874)]
# crop_0_0_0000.tif
# Number of matches in 0 channel:  6
# Number of matches in 1 channel:  6
# Number of matches in 2 channel:  2
# Number of matches in 3 channel:  4
# Corners: [(402351.5959284692, 5796980.828371604), (413970.1945961892, 5796558.700152774), (413514.6888397823, 5777602.654717458), (401896.09017206234, 5778024.782936288)]
# crop_4_2_0000.tif
# Number of matches in 0 channel:  124
# Number of matches in 1 channel:  168
# Number of matches in 2 channel:  113
# Number of matches in 3 channel:  126
# ...
